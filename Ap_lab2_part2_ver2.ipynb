# %%
# !git clone https://github.com/MrBoogie27/automatic_programming_2.git
# Out:
# fatal: destination path 'automatic_programming_2' already exists and is not an empty directory.

# %%
# !mv -v ./automatic_programming_2/* ./
# Out:
# mv: cannot stat './automatic_programming_2/*': No such file or directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp ./drive/MyDrive/AP2/train_1prcnt.json .
# !cp ./drive/MyDrive/AP2/train_3prcnt.json .
# !cp ./drive/MyDrive/AP2/train_10prcnt.json .
# !cp ./drive/MyDrive/AP2/val.json .
# !cp ./drive/MyDrive/AP2/new_vocab.vocab .

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
# !pip install cython
# !python2 setup.py install
# Out:
# ...
# running install
# running bdist_egg
# running egg_info
# writing requirements to G_RLForNPS.egg-info/requires.txt
# writing G_RLForNPS.egg-info/PKG-INFO
# writing top-level names to G_RLForNPS.egg-info/top_level.txt
# writing dependency_links to G_RLForNPS.egg-info/dependency_links.txt
# reading manifest file 'G_RLForNPS.egg-info/SOURCES.txt'
# writing manifest file 'G_RLForNPS.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# copying nps/network.py -> build/lib.linux-x86_64-2.7/nps
# running build_ext
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/nps
# copying build/lib.linux-x86_64-2.7/nps/reinforce.py -> build/bdist.linux-x86_64/egg/nps
# copying build/lib.linux-x86_64-2.7/nps/train.py -> build/bdist.linux-x86_64/egg/nps
# copying build/lib.linux-x86_64-2.7/nps/evaluate.py -> build/bdist.linux-x86_64/egg/nps
# ...

# %%
# !rm -r exps/

# %%
# %%time
# !python2 ./cmds/train_cmd.py --kernel_size 3 \
             --conv_stack "64,64,64" \
             --fc_stack "512" \
             --tgt_embedding_size 256 \
             --lstm_hidden_size 256 \
             --nb_lstm_layers 2 \
             \
             --signal supervised \
             --nb_ios 5 \
             --nb_epochs 15 \
             --optim_alg Adam \
             --batch_size 128 \
             --learning_rate 1e-4 \
             --beta 1e-5 \
             \
             --train_file train_1prcnt.json \
             --val_file val.json \
             --vocab new_vocab.vocab \
             --result_folder exps/supervised_learn_grammar \
             \
             --learn_syntax \
             \
             --use_cuda
# Out:
# 100% 79/79 [01:42<00:00,  1.03s/it]
#   0% 0/20 [00:00<?, ?it/s]/usr/local/lib/python2.7/dist-packages/G_RLForNPS-0.0.1.dev1-py2.7-linux-x86_64.egg/nps/data.py:168: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /usr/local/lib/python2.7/dist-packages/G_RLForNPS-0.0.1.dev1-py2.7-linux-x86_64.egg/nps/data.py:169: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /usr/local/lib/python2.7/dist-packages/G_RLForNPS-0.0.1.dev1-py2.7-linux-x86_64.egg/nps/data.py:191: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /usr/local/lib/python2.7/dist-packages/G_RLForNPS-0.0.1.dev1-py2.7-linux-x86_64.egg/nps/data.py:192: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# ...

# %%
# %%time
# !python2 ./cmds/train_cmd.py --kernel_size 3 \
             --conv_stack "64,64,64" \
             --fc_stack "512" \
             --tgt_embedding_size 256 \
             --lstm_hidden_size 256 \
             --nb_lstm_layers 2 \
             \
             --signal supervised \
             --nb_ios 5 \
             --nb_epochs 10 \
             --optim_alg Adam \
             --batch_size 128 \
             --learning_rate 1e-4 \
             --beta 1e-5 \
             \
             --train_file train_3prcnt.json \
             --val_file val.json \
             --vocab new_vocab.vocab \
             --result_folder exps/supervised_learn_grammar \
             \
             --learn_syntax \
             \
             --use_cuda
# Out:
# 100% 30000/30000 [00:23<00:00, 1251.55it/s]
# 100% 235/235 [04:09<00:00,  1.16it/s]
# 100% 2500/2500 [00:02<00:00, 1072.23it/s]
#   0% 0/20 [00:00<?, ?it/s]/usr/local/lib/python2.7/dist-packages/G_RLForNPS-0.0.1.dev1-py2.7-linux-x86_64.egg/nps/data.py:168: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /usr/local/lib/python2.7/dist-packages/G_RLForNPS-0.0.1.dev1-py2.7-linux-x86_64.egg/nps/data.py:169: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /usr/local/lib/python2.7/dist-packages/G_RLForNPS-0.0.1.dev1-py2.7-linux-x86_64.egg/nps/data.py:191: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /usr/local/lib/python2.7/dist-packages/G_RLForNPS-0.0.1.dev1-py2.7-linux-x86_64.egg/nps/data.py:192: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# ...

# %%
# %%time
# !python2 ./cmds/train_cmd.py --kernel_size 3 \
             --conv_stack "64,64,64" \
             --fc_stack "512" \
             --tgt_embedding_size 256 \
             --lstm_hidden_size 256 \
             --nb_lstm_layers 2 \
             \
             --signal supervised \
             --nb_ios 5 \
             --nb_epochs 5 \
             --optim_alg Adam \
             --batch_size 128 \
             --learning_rate 1e-4 \
             --beta 1e-5 \
             \
             --train_file train_10prcnt.json \
             --val_file val.json \
             --vocab new_vocab.vocab \
             --result_folder exps/supervised_learn_grammar \
             \
             --learn_syntax \
             \
             --use_cuda
# Out:
# 100% 37096/37096 [00:29<00:00, 1261.53it/s]
# 100% 290/290 [05:13<00:00,  1.05s/it]
# 100% 2500/2500 [00:01<00:00, 1251.90it/s]
#   0% 0/20 [00:00<?, ?it/s]/usr/local/lib/python2.7/dist-packages/G_RLForNPS-0.0.1.dev1-py2.7-linux-x86_64.egg/nps/data.py:173: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /usr/local/lib/python2.7/dist-packages/G_RLForNPS-0.0.1.dev1-py2.7-linux-x86_64.egg/nps/data.py:174: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /usr/local/lib/python2.7/dist-packages/G_RLForNPS-0.0.1.dev1-py2.7-linux-x86_64.egg/nps/data.py:196: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /usr/local/lib/python2.7/dist-packages/G_RLForNPS-0.0.1.dev1-py2.7-linux-x86_64.egg/nps/data.py:197: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# ...

# %%
# %%time
# !python2 ./cmds/eval_cmd.py --model_weights exps/supervised_learn_grammar/Weights/best.model \
            \
            --vocabulary new_vocab.vocab \
            --dataset val.json \
            --eval_nb_ios 5 \
            --eval_batch_size 8 \
            --output_path exps/supervised_learn_grammar/Results/ValidationSet_ \
            \
            --beam_size 64 \
            --top_k 10 \
            --dump_programs \
            --use_grammar \
            \
            --use_cuda
# Out:
# /usr/local/lib/python2.7/dist-packages/torch/serialization.py:593: SourceChangeWarning: source code of class 'nps.network.MultiIOProgramDecoder' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
#   0% 0/313 [00:00<?, ?it/s]/usr/local/lib/python2.7/dist-packages/G_RLForNPS-0.0.1.dev1-py2.7-linux-x86_64.egg/nps/data.py:173: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /usr/local/lib/python2.7/dist-packages/G_RLForNPS-0.0.1.dev1-py2.7-linux-x86_64.egg/nps/data.py:174: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /usr/local/lib/python2.7/dist-packages/G_RLForNPS-0.0.1.dev1-py2.7-linux-x86_64.egg/nps/data.py:196: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# ...
